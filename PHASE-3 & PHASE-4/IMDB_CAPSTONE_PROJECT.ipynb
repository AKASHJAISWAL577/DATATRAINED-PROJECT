# %% [markdown]
# # IMDB_CAPSTONE_PROJECT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import zscore
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import QuantileTransformer
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV

from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.linear_model import Lasso
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.datasets import make_regression
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("data1.csv")
df1
# Out:
#       Unnamed: 0  S No.                                          MovieName  \
# 0              0      1                                    The Dark Knight
# 1              1      2      The Lord of the Rings: The Return of the King
# 2              2      3                                          Inception
# 3              3      4  The Lord of the Rings: The Fellowship of the Ring
# 4              4      5              The Lord of the Rings: The Two Towers
# ...          ...    ...                                                ...
# 1738        1738  1,739                                              Radhe
# 1739        1739  1,740                                             Race 3
# 1740        1740  1,741                                  Angels Apocalypse
# 1741        1741  1,742                              The Cost of Deception
# 1742        1742  1,743                                            Sadak 2
#
#       Duration  Year  Rating Metascore           Director1        Director2  \
# 0          152  2008     9.0        84  Christopher Nolan               NaN
# 1          201  2003     9.0        94      Peter Jackson               NaN
# 2          148  2010     8.8        74  Christopher Nolan               NaN
# 3          178  2001     8.8        92      Peter Jackson               NaN
# 4          179  2002     8.8        87      Peter Jackson               NaN
# ...        ...   ...     ...       ...                 ...              ...
# 1738       109  2021     1.9       Nan        Prabhu Deva               NaN
# 1739       160  2018     1.9       Nan       Remo D'Souza               NaN
# 1740        85  2015     1.7       Nan           Sean Cain   Enzo Zelocchi
# 1741       125  2021     1.5       Nan      Keith English               NaN
# 1742       133  2020     1.2       Nan       Mahesh Bhatt               NaN
#
#      Director3
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 1738       NaN
# 1739       NaN
# 1740       NaN
# 1741       NaN
# 1742       NaN
#
# [1743 rows x 10 columns]

# %%
df2=pd.read_csv("data2.csv")
df2
# Out:
#       Unnamed: 0                                          MovieName  \
# 0              0                                    The Dark Knight
# 1              1      The Lord of the Rings: The Return of the King
# 2              2                                          Inception
# 3              3  The Lord of the Rings: The Fellowship of the Ring
# 4              4              The Lord of the Rings: The Two Towers
# ...          ...                                                ...
# 1738        1738                                              Radhe
# 1739        1739                                             Race 3
# 1740        1740                                  Angels Apocalypse
# 1741        1741                              The Cost of Deception
# 1742        1742                                            Sadak 2
#
#                    Star1                  Star2               Star3  \
# 0         Christian Bale           Heath Ledger       Aaron Eckhart
# 1            Elijah Wood        Viggo Mortensen        Ian McKellen
# 2      Leonardo DiCaprio   Joseph Gordon-Levitt         Elliot Page
# 3            Elijah Wood           Ian McKellen       Orlando Bloom
# 4            Elijah Wood           Ian McKellen     Viggo Mortensen
# ...                  ...                    ...                 ...
# 1738         Salman Khan           Disha Patani       Randeep Hooda
# 1739         Anil Kapoor            Salman Khan          Bobby Deol
# 1740       Enzo Zelocchi          Jana Rochelle   Ryan C.F. Buckley
# 1741   Vivianne Bánovits           András Mózes         Barna Bokor
# 1742          Alia Bhatt            Sanjay Dutt       Priyanka Bose
#
#                       Star4  Genre1      Genre2     Genre3 Gross_Collection  \
# 0             Michael Caine  Action       Crime      Drama           534.86
# 1             Orlando Bloom  Action   Adventure      Drama           377.85
# 2              Ken Watanabe  Action   Adventure     Sci-Fi           292.58
# 3                 Sean Bean  Action   Adventure      Drama           315.54
# 4             Orlando Bloom  Action   Adventure      Drama           342.55
# ...                     ...     ...         ...        ...              ...
# 1738          Jackie Shroff  Action       Crime   Thriller              Nan
# 1739   Jacqueline Fernandez  Action       Crime   Thriller             1.69
# 1740        William Kirkham  Action     Fantasy     Sci-Fi              Nan
# 1741        Gabriella Gubás  Action       Crime      Drama              Nan
# 1742      Aditya Roy Kapoor  Action       Drama        Nan              Nan
#
#      Certification      votes
# 0           PG-13   2,714,822
# 1           PG-13   1,885,048
# 2           PG-13   2,409,922
# 3           PG-13   1,913,811
# 4           PG-13   1,701,534
# ...            ...        ...
# 1738        TV-MA     178,711
# 1739    Not Rated      47,508
# 1740           Nan     42,911
# 1741           Nan     39,406
# 1742        TV-MA      96,240
#
# [1743 rows x 12 columns]

# %%
df=pd.DataFrame()

# %%
df = pd.merge(df1,df2)
df
# Out:
#       Unnamed: 0  S No.                                          MovieName  \
# 0              0      1                                    The Dark Knight
# 1              1      2      The Lord of the Rings: The Return of the King
# 2              2      3                                          Inception
# 3              3      4  The Lord of the Rings: The Fellowship of the Ring
# 4              4      5              The Lord of the Rings: The Two Towers
# ...          ...    ...                                                ...
# 1738        1738  1,739                                              Radhe
# 1739        1739  1,740                                             Race 3
# 1740        1740  1,741                                  Angels Apocalypse
# 1741        1741  1,742                              The Cost of Deception
# 1742        1742  1,743                                            Sadak 2
#
#       Duration  Year  Rating Metascore           Director1        Director2  \
# 0          152  2008     9.0        84  Christopher Nolan               NaN
# 1          201  2003     9.0        94      Peter Jackson               NaN
# 2          148  2010     8.8        74  Christopher Nolan               NaN
# 3          178  2001     8.8        92      Peter Jackson               NaN
# 4          179  2002     8.8        87      Peter Jackson               NaN
# ...        ...   ...     ...       ...                 ...              ...
# 1738       109  2021     1.9       Nan        Prabhu Deva               NaN
# 1739       160  2018     1.9       Nan       Remo D'Souza               NaN
# 1740        85  2015     1.7       Nan           Sean Cain   Enzo Zelocchi
# 1741       125  2021     1.5       Nan      Keith English               NaN
# 1742       133  2020     1.2       Nan       Mahesh Bhatt               NaN
#
#      Director3               Star1                  Star2               Star3  \
# 0          NaN      Christian Bale           Heath Ledger       Aaron Eckhart
# 1          NaN         Elijah Wood        Viggo Mortensen        Ian McKellen
# 2          NaN   Leonardo DiCaprio   Joseph Gordon-Levitt         Elliot Page
# 3          NaN         Elijah Wood           Ian McKellen       Orlando Bloom
# 4          NaN         Elijah Wood           Ian McKellen     Viggo Mortensen
# ...        ...                 ...                    ...                 ...
# 1738       NaN         Salman Khan           Disha Patani       Randeep Hooda
# 1739       NaN         Anil Kapoor            Salman Khan          Bobby Deol
# 1740       NaN       Enzo Zelocchi          Jana Rochelle   Ryan C.F. Buckley
# 1741       NaN   Vivianne Bánovits           András Mózes         Barna Bokor
# 1742       NaN          Alia Bhatt            Sanjay Dutt       Priyanka Bose
#
#                       Star4  Genre1      Genre2     Genre3 Gross_Collection  \
# 0             Michael Caine  Action       Crime      Drama           534.86
# 1             Orlando Bloom  Action   Adventure      Drama           377.85
# 2              Ken Watanabe  Action   Adventure     Sci-Fi           292.58
# 3                 Sean Bean  Action   Adventure      Drama           315.54
# 4             Orlando Bloom  Action   Adventure      Drama           342.55
# ...                     ...     ...         ...        ...              ...
# 1738          Jackie Shroff  Action       Crime   Thriller              Nan
# 1739   Jacqueline Fernandez  Action       Crime   Thriller             1.69
# 1740        William Kirkham  Action     Fantasy     Sci-Fi              Nan
# 1741        Gabriella Gubás  Action       Crime      Drama              Nan
# 1742      Aditya Roy Kapoor  Action       Drama        Nan              Nan
#
#      Certification      votes
# 0           PG-13   2,714,822
# 1           PG-13   1,885,048
# 2           PG-13   2,409,922
# 3           PG-13   1,913,811
# 4           PG-13   1,701,534
# ...            ...        ...
# 1738        TV-MA     178,711
# 1739    Not Rated      47,508
# 1740           Nan     42,911
# 1741           Nan     39,406
# 1742        TV-MA      96,240
#
# [1743 rows x 20 columns]

# %%
df= pd.DataFrame()

# %%
df=pd.merge(df1, df2)
df
# Out:
#       Unnamed: 0  S No.                                          MovieName  \
# 0              0      1                                    The Dark Knight
# 1              1      2      The Lord of the Rings: The Return of the King
# 2              2      3                                          Inception
# 3              3      4  The Lord of the Rings: The Fellowship of the Ring
# 4              4      5              The Lord of the Rings: The Two Towers
# ...          ...    ...                                                ...
# 1738        1738  1,739                                              Radhe
# 1739        1739  1,740                                             Race 3
# 1740        1740  1,741                                  Angels Apocalypse
# 1741        1741  1,742                              The Cost of Deception
# 1742        1742  1,743                                            Sadak 2
#
#       Duration  Year  Rating Metascore           Director1        Director2  \
# 0          152  2008     9.0        84  Christopher Nolan               NaN
# 1          201  2003     9.0        94      Peter Jackson               NaN
# 2          148  2010     8.8        74  Christopher Nolan               NaN
# 3          178  2001     8.8        92      Peter Jackson               NaN
# 4          179  2002     8.8        87      Peter Jackson               NaN
# ...        ...   ...     ...       ...                 ...              ...
# 1738       109  2021     1.9       Nan        Prabhu Deva               NaN
# 1739       160  2018     1.9       Nan       Remo D'Souza               NaN
# 1740        85  2015     1.7       Nan           Sean Cain   Enzo Zelocchi
# 1741       125  2021     1.5       Nan      Keith English               NaN
# 1742       133  2020     1.2       Nan       Mahesh Bhatt               NaN
#
#      Director3               Star1                  Star2               Star3  \
# 0          NaN      Christian Bale           Heath Ledger       Aaron Eckhart
# 1          NaN         Elijah Wood        Viggo Mortensen        Ian McKellen
# 2          NaN   Leonardo DiCaprio   Joseph Gordon-Levitt         Elliot Page
# 3          NaN         Elijah Wood           Ian McKellen       Orlando Bloom
# 4          NaN         Elijah Wood           Ian McKellen     Viggo Mortensen
# ...        ...                 ...                    ...                 ...
# 1738       NaN         Salman Khan           Disha Patani       Randeep Hooda
# 1739       NaN         Anil Kapoor            Salman Khan          Bobby Deol
# 1740       NaN       Enzo Zelocchi          Jana Rochelle   Ryan C.F. Buckley
# 1741       NaN   Vivianne Bánovits           András Mózes         Barna Bokor
# 1742       NaN          Alia Bhatt            Sanjay Dutt       Priyanka Bose
#
#                       Star4  Genre1      Genre2     Genre3 Gross_Collection  \
# 0             Michael Caine  Action       Crime      Drama           534.86
# 1             Orlando Bloom  Action   Adventure      Drama           377.85
# 2              Ken Watanabe  Action   Adventure     Sci-Fi           292.58
# 3                 Sean Bean  Action   Adventure      Drama           315.54
# 4             Orlando Bloom  Action   Adventure      Drama           342.55
# ...                     ...     ...         ...        ...              ...
# 1738          Jackie Shroff  Action       Crime   Thriller              Nan
# 1739   Jacqueline Fernandez  Action       Crime   Thriller             1.69
# 1740        William Kirkham  Action     Fantasy     Sci-Fi              Nan
# 1741        Gabriella Gubás  Action       Crime      Drama              Nan
# 1742      Aditya Roy Kapoor  Action       Drama        Nan              Nan
#
#      Certification      votes
# 0           PG-13   2,714,822
# 1           PG-13   1,885,048
# 2           PG-13   2,409,922
# 3           PG-13   1,913,811
# 4           PG-13   1,701,534
# ...            ...        ...
# 1738        TV-MA     178,711
# 1739    Not Rated      47,508
# 1740           Nan     42,911
# 1741           Nan     39,406
# 1742        TV-MA      96,240
#
# [1743 rows x 20 columns]

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1743 entries, 0 to 1742
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S No.             1743 non-null   object
#  1   MovieName         1743 non-null   object
#  2   Duration          1743 non-null   int64
#  3   Year              1743 non-null   int64
#  4   Rating            1743 non-null   float64
#  5   Metascore         1743 non-null   object
#  6   Director1         1743 non-null   object
#  7   Director2         113 non-null    object
#  8   Director3         12 non-null     object
#  9   Star1             1743 non-null   object
#  10  Star2             1743 non-null   object
#  11  Star3             1743 non-null   object
#  12  Star4             1743 non-null   object
#  13  Genre1            1743 non-null   object
#  14  Genre2            1743 non-null   object
#  15  Genre3            1743 non-null   object
#  16  Gross_Collection  1743 non-null   object
#  17  Certification     1743 non-null   object
#  18  votes             1743 non-null   object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 272.3+ KB

# %%
#value counts for each feature data
for i in df.columns:
    print(df[i].value_counts())
    print("no of unique values",df[i].nunique())
    print('******************')
# Out:
# 1        1
# 1,159    1
# 1,170    1
# 1,169    1
# 1,168    1
#         ..
# 578      1
# 577      1
# 576      1
# 575      1
# 1,743    1
# Name: S No., Length: 1743, dtype: int64
# no of unique values 1743
# ******************
# G                                3
# Mr                               3
# Ghost in the Shell               2
# The Italian Job                  2
# Wanted                           2
#                                 ..
# Love and Monsters                1
# Robin Hood: Prince of Thieves    1
# 28 Weeks Later                   1
# Atlantis: The Lost Empire        1
# Sadak 2                          1
# Name: MovieName, Length: 1702, dtype: int64
# no of unique values 1702
# ******************
# 107    48
# 109    42
# 100    42
# 110    41
# 102    40
#        ..
# 186     1
# 207     1
# 192     1
# 213     1
# 78      1
# Name: Duration, Length: 119, dtype: int64
# no of unique values 119
# ******************
# 2016    78
# 2014    76
# 2018    70
# 2011    68
# 2019    67
#         ..
# 1954     1
# 1932     1
# 1948     1
# 1949     1
# 1965     1
# Name: Year, Length: 74, dtype: int64
# no of unique values 74
# ******************
# 6.2    92
# 6.6    88
# 6.1    86
# 6.4    81
# 6.3    77
#        ..
# 2.6     1
# 2.1     1
# 1.7     1
# 1.5     1
# 1.2     1
# Name: Rating, Length: 67, dtype: int64
# no of unique values 67
# ******************
# Nan    184
# 51      42
# 48      41
# 49      40
# 40      39
#       ...
# 93       2
# 92       1
# 20       1
# 11       1
# 88       1
# Name: Metascore, Length: 87, dtype: int64
# no of unique values 87
# ******************
# Michael Bay          15
# Tony Scott           13
# Steven Spielberg     13
# Roland Emmerich      12
# Antoine Fuqua        12
#                      ..
# Adam McKay            1
# Rob Marshall          1
# Jeymes Samuel         1
# John McTiernan        1
# Mahesh Bhatt          1
# Name: Director1, Length: 943, dtype: int64
# no of unique values 943
# ******************
#  Lilly Wachowski           5
#  Joe Russo                 5
#  Espen Sandberg            4
#  Brian Taylor              4
#  Christopher Miller        3
#                           ..
#  Kleber Mendonça Filho     1
#  Carlos López Estrada      1
#  David Leitch              1
#  Akshat Verma              1
#  Enzo Zelocchi             1
# Name: Director2, Length: 90, dtype: int64
# no of unique values 90
# ******************
#  Rodney Rothman             1
#  Gowtham Selvaraj           1
#  Boyd Kirkland              1
#  Hiroyuki Okiura            1
#  Gerd Oswald                1
#  Hideaki Anno               1
#  Quentin Tarantino          1
#  Toshio Masuda              1
#  Paul Briggs                1
#  Yoann-Karl Whissell        1
#  Bob Logan                  1
#  Musa Muhammed Olayinka     1
# Name: Director3, dtype: int64
# no of unique values 12
# ******************
#  Sylvester Stallone       26
#  Arnold Schwarzenegger    23
#  Jason Statham            21
#  Bruce Willis             21
#  Mel Gibson               20
#                           ..
#  Jason Scott Lee           1
#  Gene Barry                1
#  Ayushmann Khurrana        1
#  Omar Epps                 1
#  Vivianne Bánovits         1
# Name: Star1, Length: 719, dtype: int64
# no of unique values 719
# ******************
#  Samuel L. Jackson     14
#  Laurence Fishburne     8
#  Paul Walker            7
#  Mark Wahlberg          7
#  Morgan Freeman         7
#                        ..
#  Joanne Samuel          1
#  Dev Patel              1
#  Mel Gibson             1
#  Helena Zengel          1
#  András Mózes           1
# Name: Star2, Length: 1157, dtype: int64
# no of unique values 1157
# ******************
#  Willem Dafoe         7
#  Morgan Freeman       7
#  Samuel L. Jackson    7
#  Rosario Dawson       6
#  Mark Ruffalo         6
#                      ..
#  Julie Estelle        1
#  Mahershala Ali       1
#  Tate Donovan         1
#  Jennifer Saunders    1
#  Priyanka Bose        1
# Name: Star3, Length: 1322, dtype: int64
# no of unique values 1322
# ******************
#  Famke Janssen        5
#  Don Cheadle          5
#  James Doohan         5
#  Jason Statham        5
#  Vincent D'Onofrio    5
#                      ..
#  Waluscha D'Souza     1
#  Saïd Taghmaoui       1
#  Rishi Kapoor         1
#  Marilyn Bautista     1
#  Aditya Roy Kapoor    1
# Name: Star4, Length: 1439, dtype: int64
# no of unique values 1439
# ******************
# Action       1674
# Animation      69
# Name: Genre1, dtype: int64
# no of unique values 2
# ******************
#  Adventure    635
#  Crime        341
#  Comedy       231
#  Drama        206
#  Action        69
#  Thriller      64
#  Sci-Fi        60
#  Horror        49
#  Biography     38
#  Mystery       22
#  Fantasy       22
# Nan             2
#  War            1
#  Romance        1
#  Sport          1
#  Family         1
# Name: Genre2, dtype: int64
# no of unique values 16
# ******************
#  Drama        330
#  Thriller     310
#  Sci-Fi       225
#  Crime        167
# Nan           142
#  Comedy       140
#  Fantasy      120
#  Horror        60
#  Adventure     60
#  Mystery       40
#  History       40
#  Romance       30
#  Family        22
#  War           20
#  Sport         16
#  Biography     11
#  Western        8
#  Music          1
#  Musical        1
# Name: Genre3, dtype: int64
# no of unique values 19
# ******************
# Nan       276
# 0.03        8
# 0.01        7
# 0.04        5
# 0.10        5
#          ...
# 67.33       1
# 93.43       1
# 144.53      1
# 1.36        1
# 1.69        1
# Name: Gross_Collection, Length: 1357, dtype: int64
# no of unique values 1357
# ******************
# R             702
# PG-13         633
# PG            187
# Not Rated     123
# TV-MA          38
# UA             15
# G              12
# Nan            10
# TV-14           8
# Approved        4
# U               3
# Passed          2
# M               2
# A               1
# M/PG            1
# TV-PG           1
# 16+             1
# Name: Certification, dtype: int64
# no of unique values 17
# ******************
# 55,269     2
# 57,986     2
# 107,271    2
# 76,349     2
# 29,343     2
#           ..
# 50,916     1
# 134,143    1
# 200,399    1
# 283,345    1
# 96,240     1
# Name: votes, Length: 1731, dtype: int64
# no of unique values 1731
# ******************

# %%
df.replace("Nan", np.nan ,inplace=True)

# %%
df.isnull().sum()
# Out:
# S No.                  0
# MovieName              0
# Duration               0
# Year                   0
# Rating                 0
# Metascore            184
# Director1              0
# Director2           1630
# Director3           1731
# Star1                  0
# Star2                  1
# Star3                  1
# Star4                  2
# Genre1                 0
# Genre2                 2
# Genre3               142
# Gross_Collection     276
# Certification         10
# votes                  0
# dtype: int64

# %%
df.drop(["Director2","Director3"],axis=1, inplace=True)

# %% [markdown]
# using mode to fill null values for object columns-Metascore,Certification and genre 3

# %%
df['Metascore']=df['Metascore'].fillna(df['Metascore'].mode()[0])
df['Certification'] = df['Certification'].fillna(df['Certification'].mode()[0])
df['Genre3'] =df['Genre3'].fillna(df['Genre3'].mode()[0])

# %% [markdown]
# First we converted column Gross Collection to float datatype and then used mean to fill null values.

# %%
df['Gross_Collection'] = df['Gross_Collection'].astype(float)
df['Gross_Collection'] = df['Gross_Collection'].fillna(df['Gross_Collection'].mean())

# %%
df.isnull().sum().sum()
# Out:
# 6

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# All null values have been treated or removed.No duplicates are there in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1739 entries, 0 to 1742
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S No.             1739 non-null   object
#  1   MovieName         1739 non-null   object
#  2   Duration          1739 non-null   int64
#  3   Year              1739 non-null   int64
#  4   Rating            1739 non-null   float64
#  5   Metascore         1739 non-null   object
#  6   Director1         1739 non-null   object
#  7   Star1             1739 non-null   object
#  8   Star2             1739 non-null   object
#  9   Star3             1739 non-null   object
#  10  Star4             1739 non-null   object
#  11  Genre1            1739 non-null   object
#  12  Genre2            1739 non-null   object
#  13  Genre3            1739 non-null   object
#  14  Gross_Collection  1739 non-null   float64
#  15  Certification     1739 non-null   object
#  16  votes             1739 non-null   object
# dtypes: float64(2), int64(2), object(13)
# memory usage: 244.5+ KB

# %% [markdown]
# GTreatings all columns which should be integer datatype but are object datatype

# %%
df['Metascore']= df['Metascore'].astype(int)
df['votes']=df['votes'].str.replace(',','').astype(int)
df['S No.'] = df['S No.'].str.replace(',','').astype(int)

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['S No.', 'MovieName', 'Duration', 'Year', 'Rating', 'Metascore',
#        'Director1', 'Star1', 'Star2', 'Star3', 'Star4', 'Genre1', 'Genre2',
#        'Genre3', 'Gross_Collection', 'Certification', 'votes'],
#       dtype='object')

# %% [markdown]
# # Duration

# %%
sns.displot(data=df, x="Duration",)

# %% [markdown]
# Most movies are 90 to 120 minutes long.
# Very less movies are there which are less than 60 minutes or more than 200 minutes

# %% [markdown]
# # YEAR

# %%
# Number of movies launched in the decades
sns.displot(pd.cut(df['Year'], bins=range(1970,2031,10), right=False,labels=range(1970, 2030, 10)))
plt.show()

# %% [markdown]
# Most movies have been launched in the decade of 2000-2010.

# %% [markdown]
# # Relation between years and ratings

# %%
sns.scatterplot(x=df["Year"][df["Year"]>1980],y=df["Rating"])
plt.show()

# %% [markdown]
# Hghest rated movies have ben released in years between 2000-2010
# Some of new movies launched nbetween year 2015-2020 has been the lowest rated movies.
# Trend can be seen that old movies have mostly recieved high ratings while some of the newer movies have recieved very low ratings.

# %% [markdown]
# # Metascore

# %%
sns.histplot(x=df["Metascore"])
plt.show()

# %% [markdown]
# Metascore varies between 0 and 100 while most movies has metascore lies around 50

# %% [markdown]
# # Genre

# %%
sns.countplot(data=pd.melt(df,value_vars=["Genre1", "Genre2", "Genre3"]), y="value")
plt.show()

# %% [markdown]
# Most movies are of action genre. While crime, adventure Sci-fi and drama are most common genre

# %%
sns.countplot(y=df["Certification"])
plt.show()

# %% [markdown]
# Most movies are PG-13 and R rated

# %%
sns.set(font_scale=1)
fig_dims = (10,10)
fig, ax = plt.subplots(figsize=fig_dims)
ax=sns.scatterplot(x="Gross_Collection", y="Rating",hue="Metascore", size="Rating",data=df)
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# We can have the following Conclusions:-
#
#     -Higher rated movies have been found to have higher Gross Collection.
#     _Even with high rating and metascore ,movies have been found to be grossing below average.

# %%
f,ax=plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), vmax=.8, square=True)
plt.show()

# %% [markdown]
# Metascore and rating are co related.
#
# Gross collection and votes are co related.

# %% [markdown]
# # Preparing for machines learning

# %% [markdown]
# Dropping off columns which are not useful for Machine learning

# %%
df.columns
# Out:
# Index(['S No.', 'MovieName', 'Duration', 'Year', 'Rating', 'Metascore',
#        'Director1', 'Star1', 'Star2', 'Star3', 'Star4', 'Genre1', 'Genre2',
#        'Genre3', 'Gross_Collection', 'Certification', 'votes'],
#       dtype='object')

# %%
df1=df.drop(["S No.",'MovieName',],axis=1)

# %% [markdown]
# # Encoding the categorical data

# %%
from sklearn import preprocessing
le= preprocessing.LabelEncoder()
df1['Director1']=le.fit_transform(df1['Director1'])
df1['Star1']=le.fit_transform(df1['Star1'])
df1['Star2']=le.fit_transform(df1['Star2'])
df1['Star3']=le.fit_transform(df1['Star3'])
df1['Star4']=le.fit_transform(df1['Star4'])
df1['Genre1']=le.fit_transform(df1['Genre1'])
df1['Genre2']=le.fit_transform(df1['Genre2'])
df1['Genre3']=le.fit_transform(df1['Genre3'])
df1['Certification']=le.fit_transform(df1['Certification'] )

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1739 entries, 0 to 1742
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Duration          1739 non-null   int64
#  1   Year              1739 non-null   int64
#  2   Rating            1739 non-null   float64
#  3   Metascore         1739 non-null   int32
#  4   Director1         1739 non-null   int32
#  5   Star1             1739 non-null   int32
#  6   Star2             1739 non-null   int32
#  7   Star3             1739 non-null   int32
#  8   Star4             1739 non-null   int32
#  9   Genre1            1739 non-null   int32
#  10  Genre2            1739 non-null   int32
#  11  Genre3            1739 non-null   int32
#  12  Gross_Collection  1739 non-null   float64
#  13  Certification     1739 non-null   int32
#  14  votes             1739 non-null   int32
# dtypes: float64(2), int32(11), int64(2)
# memory usage: 207.2 KB

# %% [markdown]
# All columns have been converted into integer or float datatype

# %% [markdown]
# # Outlier Treatment

# %% [markdown]
# using z score

# %%
z=np.abs(zscore(df1))
dfn=df1[(z<3).all(axis=1)]
dfn
# Out:
#       Duration  Year  Rating  Metascore  Director1  Star1  Star2  Star3  \
# 7          153  2020     8.7         51        858    633    861     94
# 19         101  2003     8.4         77        654    109   1138    638
# 21         137  1986     8.4         84        363    610    756    176
# 22         145  2019     8.4         51        533    358    811     97
# 23         141  2019     8.4         51        911    163    705    976
# ...        ...   ...     ...        ...        ...    ...    ...    ...
# 1720       107  2000     3.6         14        163    351    499   1315
# 1721        95  1997     3.6         11        444    557   1040    499
# 1722        99  2017     3.6         51         26    561    336    958
# 1723        98  1996     3.5         40        192    503     44     14
# 1724        89  2011     3.5         37        754    304    501    576
#
#       Star4  Genre1  Genre2  Genre3  Gross_Collection  Certification   votes
# 7      1357       0       5       4         77.322754             12  119393
# 19      734       0       5      11          0.710000             10  595512
# 21     1039       0       1      13         85.160000             10  731852
# 22      424       0       1       3         77.322754              6   35982
# 23     1025       0       5       4         77.322754              6   31142
# ...     ...     ...     ...     ...               ...            ...     ...
# 1720    148       0       1       6         15.220000              8   35066
# 1721   1201       0       1       6         35.930000              8   56304
# 1722   1044       0       5       4         77.322754             10   33478
# 1723    276       0      11       4          3.790000             10   30242
# 1724   1168       0       1       2         38.540000              7   26862
#
# [1470 rows x 15 columns]

# %%
df1
# Out:
#       Duration  Year  Rating  Metascore  Director1  Star1  Star2  Star3  \
# 0          152  2008     9.0         84        151    119    406      2
# 1          201  2003     9.0         94        680    184   1091    462
# 2          148  2010     8.8         74        151    407    559    351
# 3          178  2001     8.8         92        680    184    424    936
# 4          179  2002     8.8         87        680    184    424   1260
# ...        ...   ...     ...        ...        ...    ...    ...    ...
# 1738       109  2021     1.9         51        699    575    273   1003
# 1739       160  2018     1.9         51        719     43    964    143
# 1740        85  2015     1.7         51        805    192    462   1078
# 1741       125  2021     1.5         51        494    691     56    111
# 1742       133  2020     1.2         51        544     24    973    978
#
#       Star4  Genre1  Genre2  Genre3  Gross_Collection  Certification    votes
# 0       897       0       4       4        534.860000              8  2714822
# 1      1014       0       1       4        377.850000              8  1885048
# 2       719       0       1      13        292.580000              8  2409922
# 3      1218       0       1       4        315.540000              8  1913811
# 4      1014       0       1       4        342.550000              8  1701534
# ...     ...     ...     ...     ...               ...            ...      ...
# 1738    513       0       4      15         77.322754             12   178711
# 1739    515       0       4      15          1.690000              6    47508
# 1740   1404       0       7      13         77.322754             10    42911
# 1741    407       0       4       4         77.322754             10    39406
# 1742     15       0       5       4         77.322754             12    96240
#
# [1739 rows x 15 columns]

# %%
(1739-1470)*100/1739
# Out:
# 15.468660149511214

# %% [markdown]
# 15.5 % has been removed in outlier treatmewnt ,which is under considerable range

# %% [markdown]
# # Skewness Treatment

# %%
dfn.skew()
# Out:
# Duration            0.817895
# Year               -0.905771
# Rating             -0.290888
# Metascore           0.112587
# Director1          -0.112025
# Star1               0.032017
# Star2              -0.027933
# Star3               0.038216
# Star4               0.034149
# Genre1              0.000000
# Genre2              1.325309
# Genre3              0.307338
# Gross_Collection    1.820684
# Certification      -0.196441
# votes               1.947497
# dtype: float64

# %% [markdown]
# We will use Power transform method to remove the skewness for columns with skewness greater than 0.5 ,except for gross collection and votes as we need to prepare models for them.

# %%
from sklearn.preprocessing import power_transform

for i in dfn.drop(["Gross_Collection",'votes'],axis=1).columns:
    if abs(dfn[f'{i}'].skew())>0.5:
        dfn[f'{i}']=power_transform(dfn[[f'{i}']],method='yeo-johnson')
        print("treated skewness for :",i)
    else:
        continue
# Out:
# treated skewness for : Duration
# treated skewness for : Year
# treated skewness for : Genre2

# %%
dfn.skew()
# Out:
# Duration            0.022449
# Year               -0.348651
# Rating             -0.290888
# Metascore           0.112587
# Director1          -0.112025
# Star1               0.032017
# Star2              -0.027933
# Star3               0.038216
# Star4               0.034149
# Genre1              0.000000
# Genre2              0.060586
# Genre3              0.307338
# Gross_Collection    1.820684
# Certification      -0.196441
# votes               1.947497
# dtype: float64

# %% [markdown]
# Skewness has been removed from asll the required columns

# %% [markdown]
# # To prepare model for Gross Collection.

# %% [markdown]
# Scaling of Independent features

# %%
X=dfn.drop(["Gross_Collection"],axis=1)
y=dfn["Gross_Collection"]
st=StandardScaler()
xf=st.fit_transform(X)
x=pd.DataFrame(data=xf, columns=X.columns)

# %% [markdown]
# Predicting the best random state

# %%
LR = LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state {i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state {i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state 0, The training accuracy is :-0.4863171031703776
# At random state 0, The test accuracy is :-0.49174373326645493
#
#
# At random state 1, The training accuracy is :-0.44236746493437473
# At random state 1, The test accuracy is :-0.5552673112485584
#
#
# At random state 2, The training accuracy is :-0.4826834422366514
# At random state 2, The test accuracy is :-0.5012331232950298
#
#
# At random state 3, The training accuracy is :-0.45738785947791893
# At random state 3, The test accuracy is :-0.5358298813712958
#
#
# At random state 4, The training accuracy is :-0.48434789212845497
# At random state 4, The test accuracy is :-0.4972990352741349
#
#
# At random state 5, The training accuracy is :-0.5099971689536116
# At random state 5, The test accuracy is :-0.44222919931960214
#
#
# At random state 6, The training accuracy is :-0.49703904408949573
# At random state 6, The test accuracy is :-0.4692480610825345
#
#
# At random state 7, The training accuracy is :-0.49912867153775786
# At random state 7, The test accuracy is :-0.4693751058411928
#
#
# At random state 8, The training accuracy is :-0.4831978038135487
# At random state 8, The test accuracy is :-0.49786441078276245
#
#
# At random state 9, The training accuracy is :-0.4581435844408517
# At random state 9, The test accuracy is :-0.5342699207180257
#
#
# At random state 10, The training accuracy is :-0.4785884097368138
# At random state 10, The test accuracy is :-0.5145318137813724
#
#
# At random state 11, The training accuracy is :-0.5164343401143925
# At random state 11, The test accuracy is :-0.4093480687087191
#
#
# At random state 12, The training accuracy is :-0.4841562058826093
# At random state 12, The test accuracy is :-0.500228909262291
#
#
# At random state 13, The training accuracy is :-0.49077936136241307
# At random state 13, The test accuracy is :-0.4880675619708643
#
#
# At random state 14, The training accuracy is :-0.4951476204413261
# At random state 14, The test accuracy is :-0.47911218814331025
#
#
# At random state 15, The training accuracy is :-0.4945432492518559
# At random state 15, The test accuracy is :-0.4757658251886875
#
#
# At random state 16, The training accuracy is :-0.49079222914083265
# At random state 16, The test accuracy is :-0.4835227259160779
#
#
# At random state 17, The training accuracy is :-0.49981207871030275
# At random state 17, The test accuracy is :-0.46901568792893766
#
#
# At random state 18, The training accuracy is :-0.5012238025989386
# At random state 18, The test accuracy is :-0.46192036425530714
#
#
# At random state 19, The training accuracy is :-0.49199430740990924
# At random state 19, The test accuracy is :-0.484361703364657
#
#
# At random state 20, The training accuracy is :-0.4629962548782597
# At random state 20, The test accuracy is :-0.5363004592639227
#
#
# At random state 21, The training accuracy is :-0.48204956548792466
# At random state 21, The test accuracy is :-0.5007629486495441
#
#
# At random state 22, The training accuracy is :-0.4902162685688156
# At random state 22, The test accuracy is :-0.48292413057072925
#
#
# At random state 23, The training accuracy is :-0.4968410624625412
# At random state 23, The test accuracy is :-0.4710459564067435
#
#
# At random state 24, The training accuracy is :-0.5058446121039384
# At random state 24, The test accuracy is :-0.4536285969058892
#
#
# At random state 25, The training accuracy is :-0.4991366683827254
# At random state 25, The test accuracy is :-0.46260486758294617
#
#
# At random state 26, The training accuracy is :-0.5030592528824183
# At random state 26, The test accuracy is :-0.45580574436005006
#
#
# At random state 27, The training accuracy is :-0.5042038024032982
# At random state 27, The test accuracy is :-0.45652928763982636
#
#
# At random state 28, The training accuracy is :-0.446871428188215
# At random state 28, The test accuracy is :-0.5462788747784819
#
#
# At random state 29, The training accuracy is :-0.48602058445727137
# At random state 29, The test accuracy is :-0.49004299269106144
#
#
# At random state 30, The training accuracy is :-0.4744485027047425
# At random state 30, The test accuracy is :-0.5150931349345955
#
#
# At random state 31, The training accuracy is :-0.4961401348099377
# At random state 31, The test accuracy is :-0.4659235505000572
#
#
# At random state 32, The training accuracy is :-0.49025294902523076
# At random state 32, The test accuracy is :-0.48504928907212863
#
#
# At random state 33, The training accuracy is :-0.5020615924473174
# At random state 33, The test accuracy is :-0.4624789434228953
#
#
# At random state 34, The training accuracy is :-0.4895565407588849
# At random state 34, The test accuracy is :-0.4853261416674369
#
#
# At random state 35, The training accuracy is :-0.45824874309313635
# At random state 35, The test accuracy is :-0.5240059316046967
#
#
# At random state 36, The training accuracy is :-0.4880739813237497
# At random state 36, The test accuracy is :-0.48984945776553224
#
#
# At random state 37, The training accuracy is :-0.4775633230202705
# At random state 37, The test accuracy is :-0.5140075803895325
#
#
# At random state 38, The training accuracy is :-0.49352017196809495
# At random state 38, The test accuracy is :-0.4611735521629674
#
#
# At random state 39, The training accuracy is :-0.5001379945008624
# At random state 39, The test accuracy is :-0.46053810012518026
#
#
# At random state 40, The training accuracy is :-0.5037712429117519
# At random state 40, The test accuracy is :-0.4575556375774593
#
#
# At random state 41, The training accuracy is :-0.4841799530305759
# At random state 41, The test accuracy is :-0.49749683759677
#
#
# At random state 42, The training accuracy is :-0.4761557134801889
# At random state 42, The test accuracy is :-0.50329103239133
#
#
# At random state 43, The training accuracy is :-0.5017507304995465
# At random state 43, The test accuracy is :-0.46403609904789167
#
#
# At random state 44, The training accuracy is :-0.49827351752819926
# At random state 44, The test accuracy is :-0.4631283740434601
#
#
# At random state 45, The training accuracy is :-0.48369633027664505
# At random state 45, The test accuracy is :-0.4980674655761754
#
#
# At random state 46, The training accuracy is :-0.48616827212578684
# At random state 46, The test accuracy is :-0.49171800943379185
#
#
# At random state 47, The training accuracy is :-0.48728268948271314
# At random state 47, The test accuracy is :-0.49162653652472255
#
#
# At random state 48, The training accuracy is :-0.4565887591539364
# At random state 48, The test accuracy is :-0.5362513950357124
#
#
# At random state 49, The training accuracy is :-0.4933960401851567
# At random state 49, The test accuracy is :-0.47398726509643474
#
#
# At random state 50, The training accuracy is :-0.5217444177240775
# At random state 50, The test accuracy is :-0.4036609567133075
#
#
# At random state 51, The training accuracy is :-0.4943060514278034
# At random state 51, The test accuracy is :-0.474582114043518
#
#
# At random state 52, The training accuracy is :-0.5066303982886349
# At random state 52, The test accuracy is :-0.45704924214482934
#
#
# At random state 53, The training accuracy is :-0.49364252380313345
# At random state 53, The test accuracy is :-0.48158880655643166
#
#
# At random state 54, The training accuracy is :-0.46904825593888266
# At random state 54, The test accuracy is :-0.5185458717390898
#
#
# At random state 55, The training accuracy is :-0.5014930811966212
# At random state 55, The test accuracy is :-0.4605067696829128
#
#
# At random state 56, The training accuracy is :-0.49424606779978386
# At random state 56, The test accuracy is :-0.47878341248809186
#
#
# At random state 57, The training accuracy is :-0.5081211694836374
# At random state 57, The test accuracy is :-0.44705350374389496
#
#
# At random state 58, The training accuracy is :-0.4972068490963698
# At random state 58, The test accuracy is :-0.47262903749962404
#
#
# At random state 59, The training accuracy is :-0.5097837048714675
# At random state 59, The test accuracy is :-0.44912261214244686
#
#
# At random state 60, The training accuracy is :-0.4830902076120702
# At random state 60, The test accuracy is :-0.5046800032953345
#
#
# At random state 61, The training accuracy is :-0.44129223732769907
# At random state 61, The test accuracy is :-0.5539097715032101
#
#
# At random state 62, The training accuracy is :-0.49428071436522025
# At random state 62, The test accuracy is :-0.48055840090971147
#
#
# At random state 63, The training accuracy is :-0.46680817481348036
# At random state 63, The test accuracy is :-0.534298055410799
#
#
# At random state 64, The training accuracy is :-0.4652192225090773
# At random state 64, The test accuracy is :-0.5306742257514385
#
#
# At random state 65, The training accuracy is :-0.46876797640935053
# At random state 65, The test accuracy is :-0.5275087021106328
#
#
# At random state 66, The training accuracy is :-0.4449930388186971
# At random state 66, The test accuracy is :-0.5614280456806507
#
#
# At random state 67, The training accuracy is :-0.451676543380799
# At random state 67, The test accuracy is :-0.5506687908252901
#
#
# At random state 68, The training accuracy is :-0.41966216345966034
# At random state 68, The test accuracy is :-0.5581186201136358
#
#
# At random state 69, The training accuracy is :-0.46845039164022984
# At random state 69, The test accuracy is :-0.5217666165322348
#
#
# At random state 70, The training accuracy is :-0.46753527407247875
# At random state 70, The test accuracy is :-0.5280324480736878
#
#
# At random state 71, The training accuracy is :-0.4797900035799688
# At random state 71, The test accuracy is :-0.5054199719348291
#
#
# At random state 72, The training accuracy is :-0.48772998159820224
# At random state 72, The test accuracy is :-0.49049956513366555
#
#
# At random state 73, The training accuracy is :-0.48671657410074065
# At random state 73, The test accuracy is :-0.48742567558671124
#
#
# At random state 74, The training accuracy is :-0.5142621401440581
# At random state 74, The test accuracy is :-0.43324739105890875
#
#
# At random state 75, The training accuracy is :-0.4818247169987001
# At random state 75, The test accuracy is :-0.5030923855845766
#
#
# At random state 76, The training accuracy is :-0.49045028794380097
# At random state 76, The test accuracy is :-0.48541221598971707
#
#
# At random state 77, The training accuracy is :-0.4789966134485293
# At random state 77, The test accuracy is :-0.5061074615799708
#
#
# At random state 78, The training accuracy is :-0.5000584719357856
# At random state 78, The test accuracy is :-0.4666592483412758
#
#
# At random state 79, The training accuracy is :-0.5183129028479949
# At random state 79, The test accuracy is :-0.4312337907771845
#
#
# At random state 80, The training accuracy is :-0.5179604629493304
# At random state 80, The test accuracy is :-0.4322453844788078
#
#
# At random state 81, The training accuracy is :-0.5039136569294511
# At random state 81, The test accuracy is :-0.4579762465259104
#
#
# At random state 82, The training accuracy is :-0.48892346278649845
# At random state 82, The test accuracy is :-0.48813445038974135
#
#
# At random state 83, The training accuracy is :-0.5232958834480079
# At random state 83, The test accuracy is :-0.40506422431900047
#
#
# At random state 84, The training accuracy is :-0.486365599250315
# At random state 84, The test accuracy is :-0.4863155579863544
#
#
# At random state 85, The training accuracy is :-0.4660733182484398
# At random state 85, The test accuracy is :-0.5181254967449425
#
#
# At random state 86, The training accuracy is :-0.46760885204978975
# At random state 86, The test accuracy is :-0.517579778140204
#
#
# At random state 87, The training accuracy is :-0.4792236363082524
# At random state 87, The test accuracy is :-0.5037825399860805
#
#
# At random state 88, The training accuracy is :-0.4700360377245315
# At random state 88, The test accuracy is :-0.5243646208358019
#
#
# At random state 89, The training accuracy is :-0.4851352508457293
# At random state 89, The test accuracy is :-0.49529342430977685
#
#
# At random state 90, The training accuracy is :-0.47959664525024803
# At random state 90, The test accuracy is :-0.5097649477740881
#
#
# At random state 91, The training accuracy is :-0.4919278791333229
# At random state 91, The test accuracy is :-0.48328815898239297
#
#
# At random state 92, The training accuracy is :-0.5050614539333479
# At random state 92, The test accuracy is :-0.4531460972474102
#
#
# At random state 93, The training accuracy is :-0.4988982644603077
# At random state 93, The test accuracy is :-0.4701556881632891
#
#
# At random state 94, The training accuracy is :-0.4653597820761165
# At random state 94, The test accuracy is :-0.5311006036928799
#
#
# At random state 95, The training accuracy is :-0.49360364978468807
# At random state 95, The test accuracy is :-0.4787264584632407
#
#
# At random state 96, The training accuracy is :-0.5047763638044195
# At random state 96, The test accuracy is :-0.4553022889982774
#
#
# At random state 97, The training accuracy is :-0.5214769939102855
# At random state 97, The test accuracy is :-0.40442643808083467
#
#
# At random state 98, The training accuracy is :-0.4752142889444205
# At random state 98, The test accuracy is :-0.5175542121741119
#
#
# At random state 99, The training accuracy is :-0.5272448229830367
# At random state 99, The test accuracy is :-0.3950018133856712

# %% [markdown]
# At random state 66,The training accuracy is :-0.444993038816971
#
# At random state 66,The test accuracy is :-0.5614280456806506

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.33,random_state=66)
print(train_x.shape,train_y.shape)
print(test_x.shape,test_y.shape)
# Out:
# (984, 14) (984,)
# (486, 14) (486,)

# %%
lr=LinearRegression()
lasso=linear_model.Lasso()
svr=SVR()
dtr=DecisionTreeRegressor()
rfr=RandomForestRegressor()
gbr=GradientBoostingRegressor()

# %%
model=[lr,lasso,svr,dtr,rfr,gbr]
for m in model:
    m.fit(train_x,train_y)
    m.score(train_x,train_y)
    predm=m.predict(test_x)
    print(f"Scores for {m} are")
    print('Mean Absolute Error:', metrics.mean_absolute_error(test_y, predm))  
    print('Mean Squared Error:', metrics.mean_squared_error(test_y, predm))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_y, predm)))
    print('R squared score: ', r2_score(test_y, predm))
    score=cross_val_score(m,train_x,train_y,cv=5)
    print("Cross Validation Score is :",score)
    print("Mean Score :",score.mean())
    print("Difference :",score.mean()-r2_score(test_y, predm))
    plt.scatter(test_y, predm)
    plt.xlabel("Actual Sales")
    plt.ylabel("Predicted Sales")
    plt.title("Actual VS Prediction")
    plt.show()
    print("==============================================\n\n\n====================================================")
# Out:
# Scores for LinearRegression() are
# Mean Absolute Error: 32.71197453475246
# Mean Squared Error: 1879.0923699356947
# Root Mean Squared Error: 43.34849905055185
# R squared score:  0.5614280456806507
# Cross Validation Score is : [0.4427487  0.42741664 0.41723387 0.4550479  0.37908997]
# Mean Score : 0.424307415701702
# Difference : -0.13712062997894875
# ==============================================
#
#
# ====================================================
# Scores for Lasso() are
# Mean Absolute Error: 32.89384300081783
# Mean Squared Error: 1892.3837631809724
# Root Mean Squared Error: 43.501537480656616
# R squared score:  0.5583258925324222
# Cross Validation Score is : [0.43652818 0.41929749 0.41853084 0.46089275 0.38969752]
# Mean Score : 0.4249893577432477
# Difference : -0.13333653478917445
# ==============================================
#
#
# ====================================================
# Scores for SVR() are
# Mean Absolute Error: 40.24176118105696
# Mean Squared Error: 3688.2332324718523
# Root Mean Squared Error: 60.7308260479952
# R squared score:  0.1391824677537773
# Cross Validation Score is : [0.14752496 0.10850758 0.02469912 0.12779522 0.11624646]
# Mean Score : 0.10495466632469949
# Difference : -0.0342278014290778
# ==============================================
#
#
# ====================================================
# Scores for DecisionTreeRegressor() are
# Mean Absolute Error: 41.25886120157878
# Mean Squared Error: 3367.297869034952
# Root Mean Squared Error: 58.02842294113249
# R squared score:  0.21408738025551277
# Cross Validation Score is : [-0.48713767 -0.07917869 -0.01322748  0.17195993  0.01832031]
# Mean Score : -0.07785272093145276
# Difference : -0.29194010118696556
# ==============================================
#
#
# ====================================================
# Scores for RandomForestRegressor() are
# Mean Absolute Error: 28.157729386699437
# Mean Squared Error: 1494.3125020041925
# Root Mean Squared Error: 38.65633844538554
# R squared score:  0.6512339867623205
# Cross Validation Score is : [0.53119861 0.52672494 0.46296981 0.56801102 0.48739174]
# Mean Score : 0.5152592218655379
# Difference : -0.13597476489678262
# ==============================================
#
#
# ====================================================
# Scores for GradientBoostingRegressor() are
# Mean Absolute Error: 27.671224292557937
# Mean Squared Error: 1428.925172768264
# Root Mean Squared Error: 37.8011266071299
# R squared score:  0.6664951039003275
# Cross Validation Score is : [0.58374671 0.5070485  0.47450214 0.5739319  0.48468396]
# Mean Score : 0.5247826412145342
# Difference : -0.1417124626857933
# ==============================================
#
#
# ====================================================

# %% [markdown]
#  It is evedient that GradientBoostingRegressor() gives the best result.Gradient boosting builds model in a sequential manner,where each subsequent model corrects the mistakes of the previous model.As the dataset we have is small.It will give the best predictive result.

# %% [markdown]
# # Hyperparameter Tuning and treating overlifting?underfitting

# %%
gbr.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
param={
       'loss':['squared_error', 'absolute_error','huber','quantile'],
    'n_estimators':[50,100,200],
    'criterion':['friedman_mse','squared_error'],
    'max_depth':[1,2],
    "min_samples_split":[2,3]
}

# %%
gv=GridSearchCV(gbr,param,refit=True)
gv.fit(train_x,train_y)
gv.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'loss': 'squared_error',
#  'max_depth': 2,
#  'min_samples_split': 3,
#  'n_estimators': 200}

# %%
GB= GradientBoostingRegressor(criterion= 'squared_error',learning_rate= 0.2,loss= 'squared_error',min_samples_split= 2,max_depth= 2,n_estimators= 200) 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=68)
GB.fit(x_train,y_train)
GB_predict_train=GB.predict(x_train)
GB_predict_test=GB.predict(x_test)
print('The r2 score is:', r2_score(y_test, GB_predict_test))
print('The mean absolute error', mean_absolute_error(y_test, GB_predict_test))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,GB_predict_test)))
# Out:
# The r2 score is: 0.6379845531135578
# The mean absolute error 31.442746473914426
# root_mean_squared_error: 43.4665640431861

# %%
import joblib
joblib.dump(GB,"gross_collection.obj")
# Out:
# ['gross_collection.obj']

# %%
GB_l=joblib.load('gross_collection.obj')

# %% [markdown]
# # To prepare model for Number of Votes

# %% [markdown]
# # Scaling of independent Features

# %%
X=dfn.drop(["votes"],axis=1)
y=dfn["votes"]
st=StandardScaler()
xf=st.fit_transform(X)
x=pd.DataFrame(data=xf, columns=x.columns)

# %% [markdown]
# # Predicting the best random state

# %%
LR = LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state {i}, The training accuracy is :{r2_score(y_train,LR_predict_train)}')
    print(f'At random state {i}, The test accuracy is :{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state 0, The training accuracy is :0.523937049727217
# At random state 0, The test accuracy is :0.5376302354192721
#
#
# At random state 1, The training accuracy is :0.4882717245427457
# At random state 1, The test accuracy is :0.6218999865494999
#
#
# At random state 2, The training accuracy is :0.5408584217171954
# At random state 2, The test accuracy is :0.517974485968925
#
#
# At random state 3, The training accuracy is :0.5092903740975291
# At random state 3, The test accuracy is :0.5698901242743356
#
#
# At random state 4, The training accuracy is :0.5439710575378425
# At random state 4, The test accuracy is :0.5150143214472036
#
#
# At random state 5, The training accuracy is :0.568280691112399
# At random state 5, The test accuracy is :0.4456135174012421
#
#
# At random state 6, The training accuracy is :0.5254500756676226
# At random state 6, The test accuracy is :0.5520185397367635
#
#
# At random state 7, The training accuracy is :0.5411052050512715
# At random state 7, The test accuracy is :0.5201473650743182
#
#
# At random state 8, The training accuracy is :0.530905934417124
# At random state 8, The test accuracy is :0.5351920578157809
#
#
# At random state 9, The training accuracy is :0.5199548119560757
# At random state 9, The test accuracy is :0.5495194113112423
#
#
# At random state 10, The training accuracy is :0.5187626785826231
# At random state 10, The test accuracy is :0.5611007230401228
#
#
# At random state 11, The training accuracy is :0.5595146262071264
# At random state 11, The test accuracy is :0.47345547119382303
#
#
# At random state 12, The training accuracy is :0.5343804325663457
# At random state 12, The test accuracy is :0.5305553755428494
#
#
# At random state 13, The training accuracy is :0.5490205784986038
# At random state 13, The test accuracy is :0.5020919551979972
#
#
# At random state 14, The training accuracy is :0.5463485768419013
# At random state 14, The test accuracy is :0.4975553397571064
#
#
# At random state 15, The training accuracy is :0.5323996648376266
# At random state 15, The test accuracy is :0.5369755955539779
#
#
# At random state 16, The training accuracy is :0.5380002938200497
# At random state 16, The test accuracy is :0.5230274568151112
#
#
# At random state 17, The training accuracy is :0.5365944923220616
# At random state 17, The test accuracy is :0.5257232612327811
#
#
# At random state 18, The training accuracy is :0.5413322155614739
# At random state 18, The test accuracy is :0.5138625870472884
#
#
# At random state 19, The training accuracy is :0.5451302561299292
# At random state 19, The test accuracy is :0.5075835435577173
#
#
# At random state 20, The training accuracy is :0.5119729794630347
# At random state 20, The test accuracy is :0.5742201444937577
#
#
# At random state 21, The training accuracy is :0.5246162595274055
# At random state 21, The test accuracy is :0.552971802298426
#
#
# At random state 22, The training accuracy is :0.536311477141912
# At random state 22, The test accuracy is :0.5151959819566763
#
#
# At random state 23, The training accuracy is :0.5357364004570064
# At random state 23, The test accuracy is :0.5312777109807731
#
#
# At random state 24, The training accuracy is :0.5471195148424538
# At random state 24, The test accuracy is :0.5063452583810542
#
#
# At random state 25, The training accuracy is :0.5365508014974248
# At random state 25, The test accuracy is :0.5230252407029613
#
#
# At random state 26, The training accuracy is :0.5458528176869333
# At random state 26, The test accuracy is :0.5024156847233725
#
#
# At random state 27, The training accuracy is :0.5567139758321098
# At random state 27, The test accuracy is :0.4701353482514117
#
#
# At random state 28, The training accuracy is :0.5045030658674315
# At random state 28, The test accuracy is :0.5863187888706504
#
#
# At random state 29, The training accuracy is :0.5299750110693332
# At random state 29, The test accuracy is :0.5409864761826952
#
#
# At random state 30, The training accuracy is :0.5195918321780999
# At random state 30, The test accuracy is :0.5690996671725173
#
#
# At random state 31, The training accuracy is :0.5341098818359988
# At random state 31, The test accuracy is :0.5301159731749774
#
#
# At random state 32, The training accuracy is :0.543584539732838
# At random state 32, The test accuracy is :0.514384801516134
#
#
# At random state 33, The training accuracy is :0.5424456571481461
# At random state 33, The test accuracy is :0.5068579576325742
#
#
# At random state 34, The training accuracy is :0.5408702940889154
# At random state 34, The test accuracy is :0.5137789741990118
#
#
# At random state 35, The training accuracy is :0.500701544478622
# At random state 35, The test accuracy is :0.5689823797790574
#
#
# At random state 36, The training accuracy is :0.5285958595827788
# At random state 36, The test accuracy is :0.5444821238564654
#
#
# At random state 37, The training accuracy is :0.5294272917547225
# At random state 37, The test accuracy is :0.5380403478703157
#
#
# At random state 38, The training accuracy is :0.5455925679948412
# At random state 38, The test accuracy is :0.49803549784420487
#
#
# At random state 39, The training accuracy is :0.5477365543160526
# At random state 39, The test accuracy is :0.5046863921043232
#
#
# At random state 40, The training accuracy is :0.5496654647229888
# At random state 40, The test accuracy is :0.4973240128728722
#
#
# At random state 41, The training accuracy is :0.532302100486773
# At random state 41, The test accuracy is :0.5360712552095122
#
#
# At random state 42, The training accuracy is :0.526594019965171
# At random state 42, The test accuracy is :0.5493318547439296
#
#
# At random state 43, The training accuracy is :0.5413535478807021
# At random state 43, The test accuracy is :0.5165894331202963
#
#
# At random state 44, The training accuracy is :0.541712403148698
# At random state 44, The test accuracy is :0.5038129949314578
#
#
# At random state 45, The training accuracy is :0.5349302982840483
# At random state 45, The test accuracy is :0.5336988418268331
#
#
# At random state 46, The training accuracy is :0.5306263025073981
# At random state 46, The test accuracy is :0.5393382109648482
#
#
# At random state 47, The training accuracy is :0.5347591521448982
# At random state 47, The test accuracy is :0.5325157157157442
#
#
# At random state 48, The training accuracy is :0.49976068236119486
# At random state 48, The test accuracy is :0.5858584952143246
#
#
# At random state 49, The training accuracy is :0.5339607253415307
# At random state 49, The test accuracy is :0.5338478568189761
#
#
# At random state 50, The training accuracy is :0.5770764593095654
# At random state 50, The test accuracy is :0.4278843905833529
#
#
# At random state 51, The training accuracy is :0.5360457140751897
# At random state 51, The test accuracy is :0.5291566104358683
#
#
# At random state 52, The training accuracy is :0.5458075894693852
# At random state 52, The test accuracy is :0.5136766943055007
#
#
# At random state 53, The training accuracy is :0.5451071880669633
# At random state 53, The test accuracy is :0.5050982072514933
#
#
# At random state 54, The training accuracy is :0.5274225884449892
# At random state 54, The test accuracy is :0.5387537781400764
#
#
# At random state 55, The training accuracy is :0.5529030701745883
# At random state 55, The test accuracy is :0.4955068044234393
#
#
# At random state 56, The training accuracy is :0.5413296718894847
# At random state 56, The test accuracy is :0.5143826735422182
#
#
# At random state 57, The training accuracy is :0.5501333627347079
# At random state 57, The test accuracy is :0.49437094506292933
#
#
# At random state 58, The training accuracy is :0.5404310321018
# At random state 58, The test accuracy is :0.522786438655249
#
#
# At random state 59, The training accuracy is :0.5532936114122686
# At random state 59, The test accuracy is :0.4961499727933034
#
#
# At random state 60, The training accuracy is :0.5369590870336587
# At random state 60, The test accuracy is :0.522224042023757
#
#
# At random state 61, The training accuracy is :0.48481114907274103
# At random state 61, The test accuracy is :0.5855042856661296
#
#
# At random state 62, The training accuracy is :0.5316927056171139
# At random state 62, The test accuracy is :0.539240530227853
#
#
# At random state 63, The training accuracy is :0.5124328110629536
# At random state 63, The test accuracy is :0.5681962548903088
#
#
# At random state 64, The training accuracy is :0.5194787039366314
# At random state 64, The test accuracy is :0.5595703353255331
#
#
# At random state 65, The training accuracy is :0.5153720597822493
# At random state 65, The test accuracy is :0.5722850290490535
#
#
# At random state 66, The training accuracy is :0.5042824462174662
# At random state 66, The test accuracy is :0.5844606044602179
#
#
# At random state 67, The training accuracy is :0.5006764854893235
# At random state 67, The test accuracy is :0.5886717599211055
#
#
# At random state 68, The training accuracy is :0.4785081283043594
# At random state 68, The test accuracy is :0.6121180039456912
#
#
# At random state 69, The training accuracy is :0.5182302092936129
# At random state 69, The test accuracy is :0.5555778865308941
#
#
# At random state 70, The training accuracy is :0.5305676676071245
# At random state 70, The test accuracy is :0.5352288409568856
#
#
# At random state 71, The training accuracy is :0.5220437456549767
# At random state 71, The test accuracy is :0.5559520032482657
#
#
# At random state 72, The training accuracy is :0.523328014229769
# At random state 72, The test accuracy is :0.5474043283896838
#
#
# At random state 73, The training accuracy is :0.5319573148158216
# At random state 73, The test accuracy is :0.5328870023489951
#
#
# At random state 74, The training accuracy is :0.5631024868133983
# At random state 74, The test accuracy is :0.4542365964026749
#
#
# At random state 75, The training accuracy is :0.5288360017451434
# At random state 75, The test accuracy is :0.5382061845665387
#
#
# At random state 76, The training accuracy is :0.54368637222926
# At random state 76, The test accuracy is :0.5021092930916753
#
#
# At random state 77, The training accuracy is :0.5157583122823969
# At random state 77, The test accuracy is :0.5697392528352376
#
#
# At random state 78, The training accuracy is :0.5478659190406905
# At random state 78, The test accuracy is :0.5064680426479062
#
#
# At random state 79, The training accuracy is :0.5501921019117169
# At random state 79, The test accuracy is :0.5036177657167872
#
#
# At random state 80, The training accuracy is :0.563115105341322
# At random state 80, The test accuracy is :0.45294410006295205
#
#
# At random state 81, The training accuracy is :0.5384097987387442
# At random state 81, The test accuracy is :0.5267052032054891
#
#
# At random state 82, The training accuracy is :0.5195204607540471
# At random state 82, The test accuracy is :0.5456250207658453
#
#
# At random state 83, The training accuracy is :0.5696935249798167
# At random state 83, The test accuracy is :0.44124656898678405
#
#
# At random state 84, The training accuracy is :0.5228961028469483
# At random state 84, The test accuracy is :0.5547890700105946
#
#
# At random state 85, The training accuracy is :0.5249333661670672
# At random state 85, The test accuracy is :0.5519808054451847
#
#
# At random state 86, The training accuracy is :0.5045136474217483
# At random state 86, The test accuracy is :0.5857146068688515
#
#
# At random state 87, The training accuracy is :0.531283481556001
# At random state 87, The test accuracy is :0.5413053645442979
#
#
# At random state 88, The training accuracy is :0.5161978510149321
# At random state 88, The test accuracy is :0.5490587150010968
#
#
# At random state 89, The training accuracy is :0.5306132780305484
# At random state 89, The test accuracy is :0.5371874197355484
#
#
# At random state 90, The training accuracy is :0.5333957398713407
# At random state 90, The test accuracy is :0.5304983011504655
#
#
# At random state 91, The training accuracy is :0.5415544717698809
# At random state 91, The test accuracy is :0.5067475613050532
#
#
# At random state 92, The training accuracy is :0.538976651181755
# At random state 92, The test accuracy is :0.5267155887906876
#
#
# At random state 93, The training accuracy is :0.5370347759712689
# At random state 93, The test accuracy is :0.5235789523322134
#
#
# At random state 94, The training accuracy is :0.5155918613285313
# At random state 94, The test accuracy is :0.5730023693153066
#
#
# At random state 95, The training accuracy is :0.5360828485588948
# At random state 95, The test accuracy is :0.5299351225388969
#
#
# At random state 96, The training accuracy is :0.5517786908989806
# At random state 96, The test accuracy is :0.49500990545758994
#
#
# At random state 97, The training accuracy is :0.5665362512022397
# At random state 97, The test accuracy is :0.45642969752759566
#
#
# At random state 98, The training accuracy is :0.5268387260030931
# At random state 98, The test accuracy is :0.5301852522425902
#
#
# At random state 99, The training accuracy is :0.5599575249969064
# At random state 99, The test accuracy is :0.47903739649426746

# %% [markdown]
# At random state 1, The training accuracy is :0.4882717245427457 , At random state 1,The test accuracy is:- 0.6218999865494999

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.33,random_state=1)
print(train_x.shape,train_y.shape)
print(test_x.shape,test_y.shape)
# Out:
# (984, 14) (984,)
# (486, 14) (486,)

# %%
model=[lr,lasso,svr,dtr,rfr,gbr]
for m in model:
    m.fit(train_x,train_y)
    m.score(train_x,train_y)
    predm=m.predict(test_x)
    print(f"Scores for {m} are")
    print('Mean Absolute Error:', metrics.mean_absolute_error(test_y, predm))  
    print('Mean Squared Error:', metrics.mean_squared_error(test_y, predm))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_y, predm)))
    print('R squared score: ', r2_score(test_y, predm))
    score=cross_val_score(m,train_x,train_y,cv=5)
    print("Cross Validation Score is :",score)
    print("Mean Score :",score.mean())
    print("Difference :",score.mean()-r2_score(test_y, predm))
    plt.scatter(test_y, predm)
    plt.xlabel("Actual Sales")
    plt.ylabel("Predicted Sales")
    plt.title("Actual VS Prediction")
    plt.show()
    print("==============================================\n\n\n====================================================")
# Out:
# Scores for LinearRegression() are
# Mean Absolute Error: 74605.10535704278
# Mean Squared Error: 10191578203.707165
# Root Mean Squared Error: 100953.34666917767
# R squared score:  0.6218999865494999
# Cross Validation Score is : [0.45651668 0.46301544 0.54442082 0.37202399 0.41449587]
# Mean Score : 0.4500945583235845
# Difference : -0.17180542822591532
# ==============================================
#
#
# ====================================================
# Scores for Lasso() are
# Mean Absolute Error: 74605.14024359427
# Mean Squared Error: 10191614667.703918
# Root Mean Squared Error: 100953.52726727244
# R squared score:  0.6218986337621899
# Cross Validation Score is : [0.45652148 0.46301261 0.5444216  0.37203337 0.41449582]
# Mean Score : 0.4500969754298406
# Difference : -0.17180165833234928
# ==============================================
#
#
# ====================================================
# Scores for SVR() are
# Mean Absolute Error: 109324.02931808037
# Mean Squared Error: 31228672595.056065
# Root Mean Squared Error: 176716.3619902132
# R squared score:  -0.15856065588909352
# Cross Validation Score is : [-0.13904002 -0.14636024 -0.20248712 -0.10235089 -0.12169587]
# Mean Score : -0.14238682718885293
# Difference : 0.01617382870024059
# ==============================================
#
#
# ====================================================
# Scores for DecisionTreeRegressor() are
# Mean Absolute Error: 80113.1049382716
# Mean Squared Error: 16271288433.462963
# Root Mean Squared Error: 127558.96061611258
# R squared score:  0.3963472337079773
# Cross Validation Score is : [0.02378741 0.3916798  0.42192814 0.27716875 0.46794925]
# Mean Score : 0.31650266938500693
# Difference : -0.07984456432297038
# ==============================================
#
#
# ====================================================
# Scores for RandomForestRegressor() are
# Mean Absolute Error: 55179.41279835391
# Mean Squared Error: 6104707009.44274
# Root Mean Squared Error: 78132.62448838347
# R squared score:  0.7735198851202394
# Cross Validation Score is : [0.65373287 0.64928448 0.70419372 0.59827671 0.67620538]
# Mean Score : 0.6563386324230824
# Difference : -0.11718125269715696
# ==============================================
#
#
# ====================================================
# Scores for GradientBoostingRegressor() are
# Mean Absolute Error: 51844.56406833724
# Mean Squared Error: 5233217622.588283
# Root Mean Squared Error: 72340.98162582729
# R squared score:  0.8058514968005364
# Cross Validation Score is : [0.64342559 0.70745593 0.74824295 0.71713391 0.68175969]
# Mean Score : 0.6996036157711556
# Difference : -0.10624788102938076
# ==============================================
#
#
# ====================================================

# %% [markdown]
# # It is evident that GradientBoostingRegressor() gives the best result.Gradient boosting builds models in a sequential manner,where each subsequent model.As the dataset we have is small.It will give the best predictive result.

# %% [markdown]
# # Hyperparameter Tuning and treating overfitting/underfitting

# %%
param1 ={
       'loss':['squared_error', 'absolute_error', 'huber'],
        'learning_rate':[0.1,0.2],
        'n_estimators':[50,100,200],
        'criterion':['friedman_mse', 'squared_error'],
        'max_depth':[1,2],
        'min_samples_split':[2,3],
        "min_samples_leaf":[1,2]       
}

# %%
gv=GridSearchCV(gbr,param1,refit=True)
gv.fit(train_x,train_y)
gv.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.2,
#  'loss': 'huber',
#  'max_depth': 2,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
GB1= GradientBoostingRegressor(criterion='squared_error',
 learning_rate= 0.2,
 loss='huber',
 max_depth= 2,
 min_samples_leaf=2,
 min_samples_split= 2,
 n_estimators= 200) 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)
GB1.fit(x_train,y_train)
GB1_predict_train=GB1.predict(x_train)
GB1_predict_test=GB1.predict(x_test)
print('The r2 score is:', r2_score(y_test, GB1_predict_test))
print('The mean absolute error', mean_absolute_error(y_test, GB1_predict_test))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,GB1_predict_test)))
# Out:
# The r2 score is: 0.7985136937157935
# The mean absolute error 53354.83622415505
# root_mean_squared_error: 73695.35952417638

# %%
import joblib
joblib.dump(GB1,"votes.obj")
# Out:
# ['votes.obj']

# %%
GB1_l=joblib.load('votes.obj')
